# %% [markdown]
# <a href="https://colab.research.google.com/github/VibhuJ01/Smart-Tic-Tac-Toe/blob/main/Tic%20Tac%20Toe%20with%20AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import os

def repeat_check():
    while 1 == 1:
        n = input_check()
        if n == 1 or n == 2 or n == 3:
            if a[n-1] == 'O' or a[n-1] == 'X':
                print('\nWrong Input! Try Again\n')
                for f1 in f:
                    print(f1)
            else:
                return n
                break
                
        elif n == 4 or n == 5 or n == 6:
            if b[n-4] == 'O' or b[n-4] == 'X':
                print('\nWrong Input! Try Again\n')
                for f1 in f:
                    print(f1)
            else:
                return n
                break
        elif n == 7 or n == 8 or n == 9:
            if c[n-7] == 'O' or c[n-7] == 'X':
                print('\nWrong Input! Try Again\n')
                for f1 in f:
                    print(f1)
            else:
                return n
                break
            
def input_check():
    while 1 == 1:
        n = input('\nEnter Location(1 - 9): ')
        print('\n')
        
        if n.isalpha() == True:
            print('\nWrong Input! Try Again\n')
            for f1 in f:
                print(f1)
        else:
            n = int(n)
            if  n>= 1 and n<= 9:
                return n
                break
            
            else:
                print('\nWrong Input! Try Again\n')
                repeat_check()
                

def win_check():
#Row Check
    for i in f:
        if(i[0] == i[1] == i[2] == 'O'):
            print("\n'O' won the Game\n")
            return 1
        
        elif(i[0] == i[1] == i[2] == 'X'):
            print("\n'X' won the Game")
            return 1

#Column Check
    for i in range(0,3):
        if(a[i] == b[i] == c[i] == 'O'):
            print("\n'O' won the Game\n")
            return 1

        elif(a[i] == b[i] == c[i] == 'X'):
            print("\n'X' won the Game\n")
            return 1

#Diagnal Check            
    if(a[0] == b[1] == c[2] == 'O'):
        print("\n'O' won the Game\n")
        return 1

    elif(a[0] == b[1] == c[2] == 'X'):
        print("\n'X' won the Game\n")
        return 1

    elif(a[2] == b[1] == c[0] == 'O'):
        print("\n'O' won the Game\n")
        return 1

    elif(a[2] == b[1] == c[0] == 'X'):
        print("\n'X' won the Game\n")
        return 1



    
def computer_input():
    import random
    print('\n\nCalculating Move',end="")
    time.sleep(0.5)
    print(".",end="")
    time.sleep(0.5)
    print(".",end="")
    time.sleep(0.5)
    print(".",end="")

#Possible Victory

# 1st Move

    if(b[1] != 'O' and b[1] != 'X'):
        n = 5
        return n

# 1st Row     
    elif(a[0] == a[1] == 'X' and a[2] != 'O'):
       n = 3
       return n  
    elif(a[1] == a[2] == 'X' and a[0] != 'O'):
       n = 1
       return n
    elif(a[0] == a[2] == 'X' and a[1] != 'O'):
       n = 2
       return n
    
# 2nd Row
    elif(b[0] == b[1] == 'X' and b[2] != 'O'):
       n = 6
       return n  
    elif(b[1] == b[2] == 'X' and b[0] != 'O'):
       n = 4
       return n
    elif(b[0] == b[2] == 'X' and b[1] != 'O'):
       n = 5
       return n
  
# 3rd Row 
    elif(c[0] == c[1] == 'X' and c[2] != 'O'):
       n = 9
       return n 
    elif(c[1] == c[2] == 'X' and c[0] != 'O'):
       n = 7
       return n
    elif(c[0] == c[2] == 'X' and c[1] != 'O'):
       n = 8
       return n


# 1st Column
    elif(a[0] == b[0] == 'X' and c[0] != 'O'):
        n = 7
        return n
    elif(a[0] == c[0] == 'X' and b[0] != 'O'):
        n = 4
        return n
    elif(b[0] == c[0] == 'X' and a[0] != 'O'):
        n = 1
        return n

# 2nd Column
    elif(a[1] == b[1] == 'X' and c[1] != 'O'):
        n = 8
        return n
    elif(a[1] == c[1] == 'X' and b[1] != 'O'):
        n = 5
        return n
    elif(b[1] == c[1] == 'X' and a[1] != 'O'):
        n = 2
        return n

# 3rd Column
    elif(a[2] == b[2] == 'X' and c[2] != 'O'):
        n = 9
        return n
    elif(a[2] == c[2] == 'X' and b[2] != 'O'):
        n = 6
        return n
    elif(b[2] == c[2] == 'X' and a[2] != 'O'):
        n = 3
        return n


# 1st Diagonal
    elif(a[0] == b[1] == 'X' and c[2] != 'O'):
        n = 9
        return n
    elif(a[0] == c[2] == 'X' and b[1] != 'O'):
        n = 5
        return n
    elif(b[1] == c[2] == 'X' and a[0] != 'O'):
        n = 1
        return n

# 2nd Diagonal
    elif(a[2] == b[1] == 'X' and c[0] != 'O'):
        n = 7
        return n
    elif(a[2] == c[0] == 'X' and b[1] != 'O'):
        n = 5
        return n
    elif(b[1] == c[0] == 'X' and a[2] != 'O'):
        n = 3
        return n


#Row Check

# 1st Move

    elif(b[1] != 'O' and b[1] != 'X'):
        n = 5
        return n

# 1st Row     
    elif(a[0] == a[1] == 'O' and a[2] != 'X'):
       n = 3
       return n
    elif(a[1] == a[2] == 'O' and a[0] != 'X'):
       n = 1
       return n
    elif(a[0] == a[2] == 'O' and a[1] != 'X'):
       n = 2
       return n
    
# 2nd Row
    elif(b[0] == b[1] == 'O' and b[2] != 'X'):
       n = 6
       return n
    elif(b[1] == b[2] == 'O' and b[0] != 'X'):
       n = 4
       return n
    elif(b[0] == b[2] == 'O' and b[1] != 'X'):
       n = 5
       return n

# 3rd Row 
    elif(c[0] == c[1] == 'O' and c[2] != 'X'):
       n = 9
       return n
    elif(c[1] == c[2] == 'O' and c[0] != 'X'):
       n = 7
       return n
    elif(c[0] == c[2] == 'O' and c[1] != 'X'):
       n = 8
       return n


#Column Check

# 1st Column
    elif(a[0] == b[0] == 'O' and c[0] != 'X'):
        n = 7
        return n

    elif(a[0] == c[0] == 'O' and b[0] != 'X'):
        n = 4
        return n

    elif(b[0] == c[0] == 'O' and a[0] != 'X'):
        n = 1
        return n

# 2nd Column
    elif(a[1] == b[1] == 'O' and c[1] != 'X'):
        n = 8
        return n

    elif(a[1] == c[1] == 'O' and b[1] != 'X'):
        n = 5
        return n

    elif(b[1] == c[1] == 'O' and a[1] != 'X'):
        n = 2
        return n

# 3rd Column
    elif(a[2] == b[2] == 'O' and c[2] != 'X'):
        n = 9
        return n

    elif(a[2] == c[2] == 'O' and b[2] != 'X'):
        n = 6
        return n

    elif(b[2] == c[2] == 'O' and a[2] != 'X'):
        n = 3
        return n


#Diagonal Check

# 1st Diagonal
    elif(a[0] == b[1] == 'O' and c[2] != 'X'):
        n = 9
        return n
    elif(a[0] == c[2] == 'O' and b[1] != 'X'):
        n = 5
        return n
    elif(b[1] == c[2] == 'O' and a[0] != 'X'):
        n = 1
        return n

# 2nd Diagonal
    elif(a[2] == b[1] == 'O' and c[0] != 'X'):
        n = 7
        return n
    elif(a[2] == c[0] == 'O' and b[1] != 'X'):
        n = 5
        return n
    elif(b[1] == c[0] == 'O' and a[2] != 'X'):
        n = 3
        return n


    else:
        while 1== 1:
            n = random.randint(1,9)
            if n == 1 or n == 2 or n == 3:
                if a[n-1] == 'O' or a[n-1] == 'X':
                    continue
                else:
                    return n
                    break
                    
            elif n == 4 or n == 5 or n == 6:
                if b[n-4] == 'O' or b[n-4] == 'X':
                    continue
                else:
                    return n
                    break
            elif n == 7 or n == 8 or n == 9:
                if c[n-7] == 'O' or c[n-7] == 'X':
                    continue
                else:
                    return n
                    break



            


#Main ->    
ans = 'y'
while ans == 'y':
    
    a = [' ',' ',' ']
    b = [' ',' ',' ']
    c = [' ',' ',' ']

    f = [' ',' ',' ']
    f[0] = a
    f[1] = b
    f[2] = c
    
    for f1 in f:
        print(f1)
    print("\n'O' goes First")
    count = 0


    while 1 == 1:
        
# 'O' Goes now
        
        n = repeat_check()
        if n == 1 or n == 2 or n == 3:       
            a[n-1] = 'O'
            f[0] = a
            for f1 in f:
                print(f1)       
        elif n == 4 or n == 5 or n == 6: 
            b[n-4] = 'O'
            f[1] = b
            for f1 in f:
                print(f1)   
        elif n == 7 or n == 8 or n == 9: 
            c[n-7] = 'O'
            f[2] = c
            for f1 in f:
                print(f1)

# Victory Check
                
        w = win_check()
        if w == 1:
            break

# Counting Number of Turns

        count = count + 2
        if count > 9:
            print('\nIts a Tie')
            break

# 'X' Goes now
              
        n = computer_input()
        time.sleep(0.5)
        print("\n\n")
        os.system("cls")
        if n == 1 or n == 2 or n == 3:       
            a[n-1] = 'X'
            f[0] = a
            for f1 in f:
                print(f1)       
        elif n == 4 or n == 5 or n == 6: 
            b[n-4] = 'X'
            f[1] = b
            for f1 in f:
                print(f1)   
        elif n == 7 or n == 8 or n == 9: 
            c[n-7] = 'X'
            f[2] = c
            for f1 in f:
                print(f1)

# Victory Check

        w = win_check()
        if w == 1:
            break
        
    ans = input('\nDo you want to play again?(y,n): ')
# Out:
# [' ', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']
#
# 'O' goes First
#
# Enter Location(1 - 9): 1
#
#
# ['O', ' ', ' ']
# [' ', ' ', ' ']
# [' ', ' ', ' ']
#
#
# Calculating Move...
#
#
# ['O', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
#
# Enter Location(1 - 9): 3
#
#
# ['O', ' ', 'O']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
#
#
# Calculating Move...
#
#
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# [' ', ' ', ' ']
#
# Enter Location(1 - 9): 8
#
#
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# [' ', 'O', ' ']
#
#
# Calculating Move...
#
#
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# ['X', 'O', ' ']
#
# Enter Location(1 - 9): 9
#
#
# ['O', 'X', 'O']
# [' ', 'X', ' ']
# ['X', 'O', 'O']
#
#
# Calculating Move...
#
#
# ['O', 'X', 'O']
# [' ', 'X', 'X']
# ['X', 'O', 'O']
#
# Enter Location(1 - 9): 4
#
#
# ['O', 'X', 'O']
# ['O', 'X', 'X']
# ['X', 'O', 'O']
#
# Its a Tie
